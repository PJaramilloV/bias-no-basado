# %%
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

filename='../data/cleaned/people_cl.csv'

people = pd.read_csv(filename)

# %%
people.drop(columns = ['Unnamed: 0'], inplace=True)
print(people.head())
# Out:
#     sex              race                         dob  age  juv_fel_count  \
# 0  Male             Other  1947-04-18 00:00:00.000000   69              0
# 1  Male  African-American  1982-01-22 00:00:00.000000   34              0
# 2  Male  African-American  1991-05-14 00:00:00.000000   24              0
# 3  Male  African-American  1993-01-21 00:00:00.000000   23              0
# 4  Male             Other  1973-01-22 00:00:00.000000   43              0
#
#    juv_misd_count  juv_other_count       compas_screening_date  decile_score  \
# 0               0                0  2013-08-14 00:00:00.000000             1
# 1               0                0  2013-01-27 00:00:00.000000             3
# 2               0                1  2013-04-14 00:00:00.000000             4
# 3               1                0  2013-01-13 00:00:00.000000             8
# 4               0                0  2013-03-26 00:00:00.000000             1
#
# ...

# %%
plt.figure(figsize=(14, 10), facecolor='grey')
sns.heatmap(people.corr(), cmap='viridis', annot=True);

# %%
df1 = people[['']]
